# %%
import os, sys
import numpy as np
import healpy as hp
import pandas as pd
import h5py
import matplotlib 
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

os.system('module load texlive/2022')

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "Times",
    "font.size"  : 13
})

matplotlib.rcParams.update({'font.size': 15})

matplotlib.rcParams['mathtext.fontset'] = 'stix'
plt.rc('text.latex', preamble=r'\usepackage{/global/cfs/cdirs/lsst/groups/WL/users/yomori/repo/nulltests_txpipe/apjfonts}')
        
#plt.rcParams["font.family"] = "Times New Roman"

plt.rcParams['axes.facecolor']   = 'w'
plt.rcParams['figure.facecolor'] = 'w'


kidscol = '#9CC363'    # light olive
descol  = 'chocolate'  # dark orange
hsccol  = '#5A8BAF'    # lightpurple

# %%
import pickle
file = open("../../desy3/TXdata/meanshear.pkl",'rb')
dic = pickle.load(file)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# matplotlib.rcParams.update({'font.size': 15})

# plt.clf()
# fig = plt.figure(figsize=(10,6),dpi=100)

# gs  = gridspec.GridSpec(3, 2, top=0.95, right=1.00, left=0.00, bottom=0.00,hspace=0.05,wspace=0.3)

# line1 = np.arange(-0.11,0.04,0.003)
# line2 = np.arange(-0.08,0.08,0.003)

# d = dic['KiDS-1000']['g_psfg']
# ax0 = plt.subplot(gs[0])
# ax0.errorbar(d['mu1'],d['meang1_psfg1'],d['stdg1_psfg1'], color='firebrick',linestyle='None',marker='o',mfc='None',capsize=3)
# ax0.errorbar(d['mu1'],d['meang2_psfg1'],d['stdg2_psfg1'], color='royalblue',linestyle='None',marker='o',mfc='None',capsize=3)
# ax0.plot(line1,np.zeros(len(line1)),color='black',linestyle='dashed')
# ax0.plot(d['mu1'],d['fitg1_psfg1'],color='firebrick')
# ax0.plot(d['mu1'],d['fitg2_psfg1'],color='royalblue')
# ax0.set_ylim([-0.003,0.003])
# ax0.set_xlim([-0.12,0.05])
# ax0.xaxis.set_tick_params(labelbottom=False)
# #ax0.set_ylabel(r'$\langle \gamma_{i} \rangle$')

# ax1 = plt.subplot(gs[1])
# ax1.errorbar(d['mu2'],d['meang1_psfg2'],d['stdg1_psfg2'], color='firebrick',linestyle='None',marker='o',mfc='None',capsize=3,label=r'$\langle \gamma_1 \rangle$')
# ax1.errorbar(d['mu2'],d['meang2_psfg2'],d['stdg2_psfg2'], color='royalblue',linestyle='None',marker='o',mfc='None',capsize=3,label=r'$\langle \gamma_2 \rangle$')
# ax1.plot(line2,np.zeros(len(line2)),color='black',linestyle='dashed')
# ax1.plot(d['mu2'],d['fitg1_psfg2'],color='firebrick')
# ax1.plot(d['mu2'],d['fitg2_psfg2'],color='royalblue')
# ax1.yaxis.set_tick_params(labelleft=False)
# ax1.xaxis.set_tick_params(labelbottom=False)
# ax1.text(0.875, 0.1, 'KiDS-1000', horizontalalignment='center', verticalalignment='center', transform=ax1.transAxes)
# ax1.set_ylim([-0.003,0.003])
# ax1.set_xlim([-0.09,0.09])
# ax1.legend(frameon=False,loc = 'upper right', ncol=2, labelspacing=0.00,handletextpad=0.00,columnspacing=0.2)


# d = dic['DES-Y3']['g_psfg']
# ax2 = plt.subplot(gs[2])
# ax2.errorbar(d['mu1'],d['meang1_psfg1']-np.mean(d['meang1_psfg1']),d['stdg1_psfg1'], color='firebrick',linestyle='None',marker='o',mfc='None',capsize=3)
# ax2.errorbar(d['mu1'],d['meang2_psfg1']-np.mean(d['meang2_psfg1']),d['stdg2_psfg1'], color='royalblue',linestyle='None',marker='o',mfc='None',capsize=3)
# ax2.plot(line1,np.zeros(len(line1)),color='black',linestyle='dashed')
# ax2.plot(d['mu1'],d['fitg1_psfg1']-np.mean(d['meang1_psfg1']),color='firebrick')
# ax2.plot(d['mu1'],d['fitg2_psfg1']-np.mean(d['meang2_psfg1']),color='royalblue')
# ax2.xaxis.set_tick_params(labelbottom=False)
# ax2.set_ylim([-0.003,0.003])
# ax2.set_xlim([-0.12,0.05])
# #ax2.set_ylabel(r'$\langle \gamma \rangle$')

# ax3 = plt.subplot(gs[3])
# ax3.errorbar(d['mu2'],d['meang1_psfg2']-np.mean(d['meang1_psfg2']),d['stdg1_psfg2'], color='firebrick',linestyle='None',marker='o',mfc='None',capsize=3)
# ax3.errorbar(d['mu2'],d['meang2_psfg2']-np.mean(d['meang2_psfg2']),d['stdg2_psfg2'], color='royalblue',linestyle='None',marker='o',mfc='None',capsize=3)
# ax3.plot(line2,np.zeros(len(line2)),color='black',linestyle='dashed')
# ax3.plot(d['mu2'],d['fitg1_psfg2']-np.mean(d['meang1_psfg2']),color='firebrick')
# ax3.plot(d['mu2'],d['fitg2_psfg2']-np.mean(d['meang2_psfg2']),color='royalblue')
# ax3.text(0.9, 0.1, 'DES-Y3', horizontalalignment='center', verticalalignment='center', transform=ax3.transAxes)
# ax3.yaxis.set_tick_params(labelleft=False)
# ax3.xaxis.set_tick_params(labelbottom=False)
# ax3.set_ylim([-0.003,0.003])
# ax3.set_xlim([-0.09,0.09])

# d = dic['HSC-Y3']['g_psfg']
# ax4 = plt.subplot(gs[4])
# ax4.errorbar(d['mu1'],d['meang1_psfg1']-np.mean(d['meang1_psfg1']),d['stdg1_psfg1'], color='firebrick',linestyle='None',marker='o',mfc='None',capsize=3)
# ax4.errorbar(d['mu1'],d['meang2_psfg1']-np.mean(d['meang2_psfg1']),d['stdg2_psfg1'], color='royalblue',linestyle='None',marker='o',mfc='None',capsize=3)
# ax4.plot(line1,np.zeros(len(line1)),color='black',linestyle='dashed')
# ax4.plot(d['mu1'],d['fitg1_psfg1']-np.mean(d['meang1_psfg1']),color='firebrick')
# ax4.plot(d['mu1'],d['fitg2_psfg1']-np.mean(d['meang2_psfg1']),color='royalblue')
# ax4.set_ylim([-0.003,0.003])
# ax4.set_xlim([-0.12,0.05])
# # ax4.set_ylabel(r'$\langle \gamma \rangle$')
# ax4.set_xlabel(r'$e_{\rm 1, PSF}$')

# ax5 = plt.subplot(gs[5])
# ax5.errorbar(d['mu2'],d['meang1_psfg2']-np.mean(d['meang1_psfg2']),d['stdg1_psfg2'], color='firebrick',linestyle='None',marker='o',mfc='None',capsize=3)
# ax5.errorbar(d['mu2'],d['meang2_psfg2']-np.mean(d['meang2_psfg2']),d['stdg2_psfg2'], color='royalblue',linestyle='None',marker='o',mfc='None',capsize=3)
# ax5.plot(line2,np.zeros(len(line2)),color='black',linestyle='dashed')
# ax5.plot(d['mu2'],d['fitg1_psfg2']-np.mean(d['meang1_psfg2']),color='firebrick')
# ax5.plot(d['mu2'],d['fitg2_psfg2']-np.mean(d['meang2_psfg2']),color='royalblue')
# ax5.set_ylim([-0.003,0.003])
# ax5.set_xlim([-0.09,0.09])
# ax5.set_xlabel(r'$e_{\rm 2, PSF}$')
# ax5.yaxis.set_tick_params(labelleft=False)
# ax5.text(0.9, 0.1, 'HSC-Y3', horizontalalignment='center', verticalalignment='center', transform=ax5.transAxes)

# fig.savefig('comp_psfg.pdf',bbox_inches='tight')

# %%
plt.clf()
fig = plt.figure(figsize=(4.5,5),dpi=100)
gs  = gridspec.GridSpec(3, 1, top=0.95, right=1.00, left=0.00, bottom=0.00,hspace=0.05,wspace=0.15)

d = dic['KiDS-1000']['g_psfg']
ax0 = plt.subplot(gs[0])
ax0.errorbar(d['mu1'],d['meang1_psfg1'],d['stdg1_psfg1'], color='firebrick',linestyle='None',marker='o',mfc='None',capsize=3)
ax0.errorbar(d['mu1'],d['meang2_psfg1'],d['stdg2_psfg1'], color='royalblue',linestyle='None',marker='o',mfc='None',capsize=3)
# ax0.plot(line1,np.zeros(len(line1)),color='black',linestyle='dashed')
ax0.plot(d['mu1'],d['fitg1_psfg1'],color='firebrick')
ax0.plot(d['mu1'],d['fitg2_psfg1'],color='royalblue')
ax0.set_ylim([-0.003,0.003])
ax0.plot([-0.12, 0.09], [0.0,0.0], ls=':', color='grey')
ax0.set_xlim([-0.12,0.09])
ax0.xaxis.set_tick_params(labelbottom=False)

d = dic['DES-Y3']['g_psfg']
ax1 = plt.subplot(gs[1])
ax1.errorbar(d['mu1'],d['meang1_psfg1']-np.mean(d['meang1_psfg1']),d['stdg1_psfg1'], color='firebrick',linestyle='None',marker='o',mfc='None',capsize=3)
ax1.errorbar(d['mu1'],d['meang2_psfg1']-np.mean(d['meang2_psfg1']),d['stdg2_psfg1'], color='royalblue',linestyle='None',marker='o',mfc='None',capsize=3)
# ax1.plot(line1,np.zeros(len(line1)),color='black',linestyle='dashed')
ax1.plot(d['mu1'],d['fitg1_psfg1']-np.mean(d['meang1_psfg1']),color='firebrick')
ax1.plot(d['mu1'],d['fitg2_psfg1']-np.mean(d['meang2_psfg1']),color='royalblue')
ax1.xaxis.set_tick_params(labelbottom=False)
ax1.set_ylim([-0.003,0.003])
ax1.plot([-0.12, 0.09], [0.0,0.0], ls=':', color='grey')
ax1.set_xlim([-0.12,0.09])
#ax2.set_ylabel(r'$\langle \gamma \rangle$')

d = dic['HSC-Y3']['g_psfg']
ax2 = plt.subplot(gs[2])
ax2.errorbar(d['mu1'],d['meang1_psfg1']-np.mean(d['meang1_psfg1']),d['stdg1_psfg1'], color='firebrick',linestyle='None',marker='o',mfc='None',capsize=3)
ax2.errorbar(d['mu1'],d['meang2_psfg1']-np.mean(d['meang2_psfg1']),d['stdg2_psfg1'], color='royalblue',linestyle='None',marker='o',mfc='None',capsize=3)
# ax2.plot(line1,np.zeros(len(line1)),color='black',linestyle='dashed')
ax2.plot(d['mu1'],d['fitg1_psfg1']-np.mean(d['meang1_psfg1']),color='firebrick')
ax2.plot(d['mu1'],d['fitg2_psfg1']-np.mean(d['meang2_psfg1']),color='royalblue')
ax2.set_ylim([-0.003,0.003])
ax2.plot([-0.12, 0.09], [0.0,0.0], ls=':', color='grey')
ax2.set_xlim([-0.12,0.09])
# ax4.set_ylabel(r'$\langle \gamma \rangle$')
ax2.set_xlabel(r'$e_{\rm 1, PSF}$')

fig.savefig('comp_gamma1.pdf',bbox_inches='tight')

# %%
plt.clf()
fig = plt.figure(figsize=(4.5,5),dpi=100)
gs  = gridspec.GridSpec(3, 1, top=0.95, right=1.00, left=0.00, bottom=0.00,hspace=0.05,wspace=0.15)

line = np.arange(0.0,1.0,0.01)

d = dic['KiDS-1000']['g_psfg']
ax0 = plt.subplot(gs[0])
ax0.errorbar(d['mu2'],d['meang1_psfg2'],d['stdg1_psfg2'], color='firebrick',linestyle='None',marker='o',mfc='None',capsize=3,label=r'$\langle \gamma_1 \rangle$')
ax0.errorbar(d['mu2'],d['meang2_psfg2'],d['stdg2_psfg2'], color='royalblue',linestyle='None',marker='o',mfc='None',capsize=3,label=r'$\langle \gamma_2 \rangle$')
# ax0.plot(line2,np.zeros(len(line2)),color='black',linestyle='dashed')
ax0.plot(d['mu2'],d['fitg1_psfg2'],color='firebrick')
ax0.plot(d['mu2'],d['fitg2_psfg2'],color='royalblue')
ax0.xaxis.set_tick_params(labelbottom=False)
ax0.set_ylim([-0.003,0.003])
ax0.plot([-0.12, 0.09], [0.0,0.0], ls=':', color='grey')
ax0.set_xlim([-0.12,0.09])
ax0.text(0.875, 0.1, 'KiDS-1000', horizontalalignment='center', verticalalignment='center', transform=ax0.transAxes)
ax0.legend(frameon=False,loc = 'upper right',ncol=2, labelspacing=0.00,handletextpad=0.00,columnspacing=0.2)

d = dic['DES-Y3']['g_psfg']
ax1 = plt.subplot(gs[1])
ax1.errorbar(d['mu2'],d['meang1_psfg2']-np.mean(d['meang1_psfg2']),d['stdg1_psfg2'], color='firebrick',linestyle='None',marker='o',mfc='None',capsize=3)
ax1.errorbar(d['mu2'],d['meang2_psfg2']-np.mean(d['meang2_psfg2']),d['stdg2_psfg2'], color='royalblue',linestyle='None',marker='o',mfc='None',capsize=3)
# ax1.plot(line2,np.zeros(len(line2)),color='black',linestyle='dashed')
ax1.plot(d['mu2'],d['fitg1_psfg2']-np.mean(d['meang1_psfg2']),color='firebrick')
ax1.plot(d['mu2'],d['fitg2_psfg2']-np.mean(d['meang2_psfg2']),color='royalblue')
ax1.xaxis.set_tick_params(labelbottom=False)
ax1.set_ylim([-0.003,0.003])
ax1.plot([-0.12, 0.09], [0.0,0.0], ls=':', color='grey')
ax1.set_xlim([-0.12,0.09])
ax1.text(0.9, 0.1, 'DES-Y3', horizontalalignment='center', verticalalignment='center', transform=ax1.transAxes)

d = dic['HSC-Y3']['g_psfg']
ax2 = plt.subplot(gs[2])
ax2.errorbar(d['mu2'],d['meang1_psfg2']-np.mean(d['meang1_psfg2']),d['stdg1_psfg2'], color='firebrick',linestyle='None',marker='o',mfc='None',capsize=3)
ax2.errorbar(d['mu2'],d['meang2_psfg2']-np.mean(d['meang2_psfg2']),d['stdg2_psfg2'], color='royalblue',linestyle='None',marker='o',mfc='None',capsize=3)
# ax2.plot(line2,np.zeros(len(line2)),color='black',linestyle='dashed')
ax2.plot(d['mu2'],d['fitg1_psfg2']-np.mean(d['meang1_psfg2']),color='firebrick')
ax2.plot(d['mu2'],d['fitg2_psfg2']-np.mean(d['meang2_psfg2']),color='royalblue')
ax2.set_ylim([-0.003,0.003])
ax2.plot([-0.12, 0.09], [0.0,0.0], ls=':', color='grey')
ax2.set_xlim([-0.12,0.09])
ax2.set_xlabel(r'$e_{\rm 2, PSF}$')
ax2.text(0.9, 0.1, 'HSC-Y3', horizontalalignment='center', verticalalignment='center', transform=ax2.transAxes)

fig.savefig('comp_gamma2.pdf',bbox_inches='tight')

# %%
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 15})

plt.clf()
fig = plt.figure(figsize=(4.5,5),dpi=100)
gs  = gridspec.GridSpec(3, 1, top=0.95, right=1.00, left=0.00, bottom=0.00,hspace=0.05,wspace=0.15)

line = np.arange(0.0,1.0,0.01)

d = dic['KiDS-1000']['g_T']
ax0 = plt.subplot(gs[0])
ax0.errorbar(d['mu'],d['meang1'],d['stdg1'], color='firebrick',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3,label=r'$\gamma_1$')
ax0.errorbar(d['mu'],d['meang2'],d['stdg2'], color='royalblue',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3,label=r'$\gamma_2$')
# ax0.plot(line,np.zeros(len(line)),color='black',linestyle='dashed')
ax0.plot(d['mu'],d['fitg1'],color='firebrick')
ax0.plot(d['mu'],d['fitg2'],color='royalblue')
ax0.set_ylim([-0.003,0.003])
ax0.plot([-0.05, 1.05], [0.0,0.0], ls=':', color='grey')
ax0.set_xlim([-0.05,1.05])
ax0.xaxis.set_tick_params(labelbottom=False)
# ax0.set_ylabel(r'$\langle \gamma \rangle$')
# ax0.text(0.875, 0.1, 'KiDS-1000', horizontalalignment='center', verticalalignment='center', transform=ax0.transAxes)
# ax0.legend(frameon=False,loc = 'upper right',ncol=2, labelspacing=0.00,handletextpad=0.00,columnspacing=0.2)

d = dic['DES-Y3']['g_T']
ax1 = plt.subplot(gs[1])
ax1.errorbar(d['mu'],d['meang1']-np.mean(d['meang1']),d['stdg1'], color='firebrick',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3)
ax1.errorbar(d['mu'],d['meang2']-np.mean(d['meang2']),d['stdg2'], color='royalblue',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3)
# ax1.plot(line,np.zeros(len(line)),color='black',linestyle='dashed')
ax1.plot(d['mu'],d['fitg1']-np.mean(d['meang1']),color='firebrick')
ax1.plot(d['mu'],d['fitg2']-np.mean(d['meang2']),color='royalblue')
# ax1.set_ylabel(r'$\langle \gamma \rangle$')
ax1.set_ylim([-0.003,0.003])
ax1.plot([-0.05, 1.05], [0.0,0.0], ls=':', color='grey')
ax1.set_xlim([-0.05,1.05])
ax1.xaxis.set_tick_params(labelbottom=False)
ax1.set_xlabel(r'T$_{gal}$')
# ax1.text(0.9, 0.1, 'DES-Y3', horizontalalignment='center', verticalalignment='center', transform=ax1.transAxes)

d = dic['HSC-Y3']['g_T']
ax2 = plt.subplot(gs[2])
ax2.errorbar(d['mu'],d['meang1']-np.mean(d['meang1']),d['stdg1'], color='firebrick',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3)
ax2.errorbar(d['mu'],d['meang2']-np.mean(d['meang2']),d['stdg2'], color='royalblue',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3)
# ax2.plot(line,np.zeros(len(line)),color='black',linestyle='dashed')
ax2.plot(d['mu'],d['fitg1']-np.mean(d['meang1']),color='firebrick')
ax2.plot(d['mu'],d['fitg2']-np.mean(d['meang2']),color='royalblue')
ax2.set_ylim([-0.003,0.003])
ax2.plot([-0.05, 1.05], [0.0,0.0], ls=':', color='grey')
ax2.set_xlim([-0.05,1.05])
# ax2.set_ylabel(r'$\langle \gamma \rangle$')
ax2.set_xlabel(r'$T_{\rm gal}$ [arcsec$^2$]')
# ax2.text(0.9, 0.1, 'HSC-Y3', horizontalalignment='center', verticalalignment='center', transform=ax2.transAxes)

fig.savefig('comp_Tgal.pdf',bbox_inches='tight')

# %%
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 15})

plt.clf()
fig = plt.figure(figsize=(4.5,5),dpi=100)
gs  = gridspec.GridSpec(3, 1, top=0.95, right=1.00, left=0.00, bottom=0.00,hspace=0.05,wspace=0.15)
line = np.arange(0.085,0.545,0.005)

d = dic['KiDS-1000']['g_psfT']
ax0 = plt.subplot(gs[0])
ax0.errorbar(d['mu'],d['meang1'],d['stdg1'], color='firebrick',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3,label=r'$\gamma_1$')
ax0.errorbar(d['mu'],d['meang2'],d['stdg2'], color='royalblue',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3,label=r'$\gamma_2$')
# ax0.plot(line,np.zeros(len(line)),color='black',linestyle='dashed')
ax0.plot(d['mu'],d['fitg1'],color='firebrick')
ax0.plot(d['mu'],d['fitg2'],color='royalblue')
ax0.set_ylim([-0.003,0.003])
ax0.plot([0.06, 0.55], [0.0,0.0], ls=':', color='grey')
ax0.set_xlim([0.06,0.55])
ax0.xaxis.set_tick_params(labelbottom=False)
# ax0.set_ylabel(r'$\langle \gamma \rangle$')
# ax0.text(0.875, 0.1, 'KiDS-1000', horizontalalignment='center', verticalalignment='center', transform=ax0.transAxes)
# ax0.legend(frameon=False,loc = 'upper right',ncol=2, labelspacing=0.00,handletextpad=0.00,columnspacing=0.2)

d = dic['DES-Y3']['g_psfT']
ax1 = plt.subplot(gs[1])
ax1.errorbar(d['mu'],d['meang1']-np.mean(d['meang1']),d['stdg1'], color='firebrick',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3)
ax1.errorbar(d['mu'],d['meang2']-np.mean(d['meang2']),d['stdg2'], color='royalblue',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3)
# ax1.plot(line,np.zeros(len(line)),color='black',linestyle='dashed')
ax1.plot(d['mu'],d['fitg1']-np.mean(d['meang1']),color='firebrick')
ax1.plot(d['mu'],d['fitg2']-np.mean(d['meang2']),color='royalblue')
ax1.set_ylim([-0.003,0.003])
ax1.plot([0.06, 0.55], [0.0,0.0], ls=':', color='grey')
ax1.set_xlim([0.06,0.55])
ax1.xaxis.set_tick_params(labelbottom=False)
# ax1.set_ylabel(r'$\langle \gamma \rangle$')
# ax1.text(0.9, 0.1, 'DES-Y3', horizontalalignment='center', verticalalignment='center', transform=ax1.transAxes)

d = dic['HSC-Y3']['g_psfT']
ax2 = plt.subplot(gs[2])
ax2.errorbar(d['mu'],d['meang1']-np.mean(d['meang1']),d['stdg1'], color='firebrick',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3)
ax2.errorbar(d['mu'],d['meang2']-np.mean(d['meang2']),d['stdg2'], color='royalblue',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3)
# ax2.plot(line,np.zeros(len(line)),color='black',linestyle='dashed')
ax2.plot(d['mu'],d['fitg1']-np.mean(d['meang1']),color='firebrick')
ax2.plot(d['mu'],d['fitg2']-np.mean(d['meang2']),color='royalblue')
ax2.set_ylim([-0.003,0.003])
ax2.plot([0.06, 0.55], [0.0,0.0], ls=':', color='grey')
ax2.set_xlim([0.06,0.55])
# ax2.set_ylabel(r'$\langle \gamma \rangle$')
ax2.set_xlabel(r'$T_{\rm PSF}$ [arcsec$^2$]')
# ax2.text(0.9, 0.1, 'HSC-Y3', horizontalalignment='center', verticalalignment='center', transform=ax2.transAxes)

fig.savefig('comp_PSFT.pdf',bbox_inches='tight')

# %%
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 15})

plt.clf()
fig = plt.figure(figsize=(4.5,5),dpi=100)
gs  = gridspec.GridSpec(3, 1, top=0.95, right=1.00, left=0.00, bottom=0.00,hspace=0.05,wspace=0.15)

line = range(10,160)

d = dic['KiDS-1000']['g_snr']
ax0 = plt.subplot(gs[0])
ax0.errorbar(d['mu'],d['meang1'],d['stdg1'], color='firebrick',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3,label=r'$\gamma_1$')
ax0.errorbar(d['mu'],d['meang2'],d['stdg2'], color='royalblue',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3,label=r'$\gamma_2$')
# ax0.plot(line,np.zeros(len(line)),color='black', linestyle='dashed')
ax0.plot(d['mu'],d['fitg1'],color='firebrick')
ax0.plot(d['mu'],d['fitg2'],color='royalblue')
ax0.set_ylim([-0.003,0.003])
ax0.plot([0, 180], [0.0,0.0], ls=':', color='grey')
ax0.set_xlim([0,180])
ax0.xaxis.set_tick_params(labelbottom=False)
# ax0.set_ylabel(r'$\langle \gamma \rangle$')
# ax0.text(0.875, 0.1, 'KiDS-1000', horizontalalignment='center', verticalalignment='center', transform=ax0.transAxes)
# ax0.legend(frameon=False,loc = 'upper right',ncol=2, labelspacing=0.00,handletextpad=0.00,columnspacing=0.2)

d = dic['DES-Y3']['g_snr']
ax1 = plt.subplot(gs[1])
ax1.errorbar(d['mu'],d['meang1']-np.mean(d['meang1']),d['stdg1'], color='firebrick',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3)
ax1.errorbar(d['mu'],d['meang2']-np.mean(d['meang2']),d['stdg2'], color='royalblue',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3)
# ax1.plot(line,np.zeros(len(line)),color='black', linestyle='dashed')
ax1.plot(d['mu'],d['fitg1']-np.mean(d['meang1']),color='firebrick')
ax1.plot(d['mu'],d['fitg2']-np.mean(d['meang2']),color='royalblue')
ax1.set_ylim([-0.003,0.003])
ax1.plot([0, 180], [0.0,0.0], ls=':', color='grey')
ax1.set_xlim([0,180])
# ax1.set_ylabel(r'$\langle \gamma \rangle$')
ax1.xaxis.set_tick_params(labelbottom=False)
# ax1.text(0.9, 0.1, 'DES-Y3', horizontalalignment='center', verticalalignment='center', transform=ax1.transAxes)

d = dic['HSC-Y3']['g_snr']
ax2 = plt.subplot(gs[2])
ax2.errorbar(d['mu'],d['meang1']-np.mean(d['meang1']),d['stdg1'], color='firebrick',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3)
ax2.errorbar(d['mu'],d['meang2']-np.mean(d['meang2']),d['stdg2'], color='royalblue',linestyle='None',marker='o',mfc='None',markersize=4,capsize=3)
# ax2.plot(line,np.zeros(len(line)),color='black', linestyle='dashed')
ax2.plot(d['mu'],d['fitg1']-np.mean(d['meang1']),color='firebrick')
ax2.plot(d['mu'],d['fitg2']-np.mean(d['meang2']),color='royalblue')
ax2.set_ylim([-0.003,0.003])
ax2.plot([0, 180], [0.0,0.0], ls=':', color='grey')
ax2.set_xlim([0,180])
# ax2.set_ylabel(r'$\langle \gamma \rangle$')
ax2.set_xlabel('SNR')
# ax2.text(0.9, 0.1, 'HSC-Y3', horizontalalignment='center', verticalalignment='center', transform=ax2.transAxes)

fig.savefig('comp_snr.pdf',bbox_inches='tight')
