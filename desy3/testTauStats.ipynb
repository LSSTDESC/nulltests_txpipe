# %% [markdown]
# # $\tau_{0+}$

# %%
import matplotlib.ticker as ticker

fig = plt.figure(figsize=(6,4.5))
img = plt.imread("/lcrc/project/SPT3G/users/ac.yomori/repo/nulltests_txpipe/desy3/taustat_gatti2021/tau0p.png")

#set first axes
ax = fig.add_subplot(1,1,1)
ax.imshow(img,  aspect='equal',alpha=0.2)
plt.axis('off')

#create second axes
newax = fig.add_axes(ax.get_position(), frameon=True)
newax.patch.set_alpha(0.0)
newax.set_xlim((0.08,300))
newax.set_ylim((-0.35e-5,1.38364779874213834e-5))
newax.set_xlabel(r'$\theta\ [{\rm arcmin}]$',size=14)
newax.set_ylabel(r'$\tau_{0+}$',size=15)
newax.set_xscale('log')
#newax.set_yscale('symlog',linthresh=1e-6)

#Change formatting of xticks
newax.xaxis.set_minor_formatter(ticker.FormatStrFormatter('%.1f'))
#plot point
y=np.loadtxt('/lcrc/project/SPT3G/users/ac.yomori/repo/nulltests_txpipe/desy3/taustat_gatti2021/tau0p.txt')
plt.errorbar(y[:,0],y[:,1],yerr=y[:,2],color='chocolate',marker='o',ls='None',ms=4)

y=np.loadtxt('/lcrc/project/SPT3G/users/ac.yomori/scratch/oneresp/tau0p.txt')
plt.errorbar(y[:,0],y[:,1],yerr=y[:,2],color='r',marker='x',ls='None',ms=4)


y=np.loadtxt('/lcrc/project/SPT3G/users/ac.yomori/repo/nulltests_txpipe/desy3/taustat_gatti2021/tau0p_template.txt')
plt.errorbar(y[:,0],y[:,1],color='chocolate')

'''
#newax.semilogx(tht,avg_rowe1_r/5,color='goldenrod',ls='--',label='avg (reserved)',marker='x',ms=5)
#newax.semilogx(tht,avg_rowe1_u/5,color='goldenrod',ls='-',label='avg (used)',marker='x',ms=5)
newax.plot([-11,-10],[1e3,1e3],'k',label='paper used mean')
newax.plot([-11,-10],[1e3,1e3],'r--',label='paper reserved mean')


tht,rowe2_r,rowe2_u=np.loadtxt('txpipe_hsc_rowe2.txt',unpack=True)
newax.semilogx(tht,rowe2_u,color='goldenrod',ls='-',label='TXPipe used mean',marker='x',ms=5)
newax.semilogx(tht,rowe2_r,color='goldenrod',ls=':',label='TXPipe reserved mean',marker='x',ms=5 )


for stype in (['u','r']):
    if stype=='u': mk='o'
    else: mk='^'
    corr  = treecorr.GGCorrelation(nbins=20, min_sep=3,max_sep=60, sep_units="arcmin", bin_slop=0)
    cat1  = treecorr.Catalog(ra=dd[stype]['ra'], dec=dd[stype]['dec'], g1=dd[stype]['e1_meas']-dd[stype]['e1_model'], g2=dd[stype]['e2_meas']-dd[stype]['e2_model'], ra_units="deg", dec_units="deg")
    cat2  = treecorr.Catalog(ra=dd[stype]['ra'], dec=dd[stype]['dec'], g1=dd[stype]['e1_model'], g2=dd[stype]['e2_model'], ra_units="deg", dec_units="deg")
    corr.process(cat1,cat2)
    plt.semilogx(np.exp(corr.meanlogr)*0.0166667, corr.xip,color='b',label='external (%s)'%stype,alpha=0.7,marker=mk,ms=4,mfc='None',ls='None')


''';
plt.gca().minorticks_off()
plt.legend(ncol=2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # $\tau_{2+}$

# %%
import matplotlib.ticker as ticker

fig = plt.figure(figsize=(6,4.5))
img = plt.imread("/lcrc/project/SPT3G/users/ac.yomori/repo/nulltests_txpipe/desy3/taustat_gatti2021/tau2p.png")

#set first axes
ax = fig.add_subplot(1,1,1)
ax.imshow(img,  aspect='equal',alpha=0.2)
plt.axis('off')

#create second axes
newax = fig.add_axes(ax.get_position(), frameon=True)
newax.patch.set_alpha(0.0)
newax.set_xlim((0.08,300))
newax.set_ylim((-0.793e-6 , 3.7685950413223142e-6))
newax.set_xlabel(r'$\theta\ [{\rm arcmin}]$',size=14)
newax.set_ylabel(r'$\theta\times\tau_{2+}$',size=15)
newax.set_xscale('log')
#newax.set_yscale('symlog',linthresh=1e-6)

#Change formatting of xticks
newax.xaxis.set_minor_formatter(ticker.FormatStrFormatter('%.1f'))
#plot point
y=np.loadtxt('/lcrc/project/SPT3G/users/ac.yomori/repo/nulltests_txpipe/desy3/taustat_gatti2021/tau2p.txt')
plt.errorbar(y[:,0],y[:,1],yerr=y[:,2],color='chocolate',marker='o',ls='None',ms=4)

y=np.loadtxt('/lcrc/project/SPT3G/users/ac.yomori/repo/nulltests_txpipe/desy3/taustat_gatti2021/tau2p_template.txt')
plt.errorbar(y[:,0],y[:,0]*y[:,1],color='chocolate')

plt.gca().minorticks_off()
plt.legend(ncol=2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # $\tau_{5+}$

# %%
import matplotlib.ticker as ticker

fig = plt.figure(figsize=(6,4.5))
img = plt.imread("/lcrc/project/SPT3G/users/ac.yomori/repo/nulltests_txpipe/desy3/taustat_gatti2021/tau5p.png")

#set first axes
ax = fig.add_subplot(1,1,1)
ax.imshow(img,  aspect='equal',alpha=0.2)
plt.axis('off')

#create second axes
newax = fig.add_axes(ax.get_position(), frameon=True)
newax.patch.set_alpha(0.0)
newax.set_xlim((0.08,300))
newax.set_ylim((-1.8916083916083916e-7,1.150e-7))
newax.set_xlabel(r'$\theta\ [{\rm arcmin}]$',size=14)
newax.set_ylabel(r'$\theta\times\tau_{5+}$',size=15)
newax.set_xscale('log')
#newax.set_yscale('symlog',linthresh=1e-6)

#Change formatting of xticks
newax.xaxis.set_minor_formatter(ticker.FormatStrFormatter('%.1f'))
#plot point
y=np.loadtxt('/lcrc/project/SPT3G/users/ac.yomori/repo/nulltests_txpipe/desy3/taustat_gatti2021/tau5p.txt')
plt.errorbar(y[:,0],y[:,1],yerr=y[:,2],color='chocolate',marker='o',ls='None',ms=4)

y=np.loadtxt('/lcrc/project/SPT3G/users/ac.yomori/repo/nulltests_txpipe/desy3/taustat_gatti2021/tau5p_template.txt')
plt.errorbar(y[:,0],y[:,0]*y[:,1],color='chocolate')


plt.gca().minorticks_off()
plt.legend(ncol=2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Fit values

# %% [markdown]
# The fit parameters in Gatto 2021 are:
# | Parameter| Sky |
# | -------- | ------- |
# | $\alpha$ | $0.001\pm0.005$    |
# | $\beta$  | $1.09\pm0.07$     |
# | $\eta$   | $-0.50\pm0.50$    |
#
# The values we obtain are:
# | Parameter| Sky |
# | -------- | ------- |
# | $\alpha$ | $+0.026\pm0.00005$    |
# | $\beta$  | $+0.010\pm0.016$     |
# | $\eta$   | $-1.980\pm0.035$    |

# %% [markdown]
# # Visually inspect the fits
